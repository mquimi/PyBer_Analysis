# %%
import matplotlib
matplotlib.__version__

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.grid()	
plt.plot(x_axis, y_axis)

# %%
#To create a figure
fig, ax = plt.subplots()

# %%
#defininf axis
ax.plot(x_axis,y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label="Boston")
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
#Object Oriented approach
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis, label='Boston', color="green", marker="d", linewidth=2,)
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')
ax.legend()
ax.grid()
ax.set_title('PyBear Fare by Month')
# Out:
# Text(0.5,1,'PyBear Fare by Month')

# %%
##BAR GRAPH

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
#Create a Horizontal Bar Chart

# %%
# Create the plot
plt.barh(x_axis, y_axis)

# %%
#if you want the data on opposite axes, switch the arguments in the barh() 
#function and run the cell again

# Create the plot
plt.barh(y_axis, x_axis)

# %%
# Create the plot.
plt.barh(x_axis, y_axis)

# %%
#To invert the y-axis to have 
#the months in ascending order
#the gca() method means "get current axes.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
#Matplotlib MATLAB plotting approach,

# %%
#Change the bar colors to magenta.
plt.barh(x_axis, y_axis, color="magenta", label="Boston")

#Add a legend for the city of Boston.
plt.legend()
#Add a title and axes labels.
plt.title('PyBer Fare by Month')
plt.xlabel("Date")
plt.ylabel("Fare($)")
#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %%
#Create a Vertical Bar Chart

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color='cyan',label='New York')

#Add a legend for the city of Boston.
ax.legend()
#Add a title and axes labels.
ax.set_title('PyBer Fare by Month')
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')

#Invert the y-axis data.
ax.invert_yaxis()

# %%
##SCATTER PLOT

# %%
##two ways to create scatter plot with MATLAB

#plt.plot()
#plt.scatter()

# %%
plt.plot()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]
plt.plot()
# Out:
# []

# %%
#we need to add a lowercase "o" as a parameter inside the parentheses. 
#This switches the plot from a line chart to a scatter plot.

#Change the color of the markers to red.
plt.plot(x_axis, y_axis, 'o', c="red")
#Add a legend for the city of Chicago.
plt.legend()
#Add a title and axes labels.
plt.title("PyBer Fare by Month")
plt.xlabel("Date")
plt.ylabel("Fare($)")
#Switch the axis so that the Fare($) data is on the x-axis.
#Add a limit for the x-axis data.
#Invert the y-axis so that January is at the top.
plt.gca().invert_xaxis()

# %%
#We will make the size of each marker equal to the data 
#floating-point decimal values of the y-axis
#plt.scatter(x_axis, y_axis, s=y_axis)

#We can adjust the size by multiplying the data in the y-axis by any value. 
#Let's multiply each data point in the y-axis by 3 and see what happens. 
#To do this, we can iterate through the y-axis data and multiply each data point by 
#3 and add it to a new list,

y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
#using the format of a line comprehension
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
#Create a Scatter Plot Using the Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
#Create a Bubble Chart Using the Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
fig, ax = plt.subplots()

#Change the color of the markers to sky blue.
ax.scatter(x_axis, y_axis, s=y_axis, color="skyblue",alpha=.2, edgecolor="black")
#Change the size of the markers to 5 times each data point.
ax.scatter(x_axis, y_axis, s = [i * 5 for i in y_axis])
#Make the color 20% transparent.

#Add a black edge color to the circles.

#Make the linewidth of the circles 2 points.

#Add a legend for the city of Boston.
ax.legend()
#Add a title.
ax.set_title("hi")
#Switch the axis so that the Fare($) data is on the x-axis.
ax.barh(x_axis,y_axis)
#Add a limit for the x-axis data.
ax.set_ylim(0, 50)
#Invert the y-axis so that January is at the top.
ax.invert_xaxis()

# %%
#Create a Pie Chart Using the MATLAB Method

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb7cdf067d0>,
#   <matplotlib.patches.Wedge at 0x7fb7cdf06fd0>,
#   <matplotlib.patches.Wedge at 0x7fb7cdefb810>,
#   <matplotlib.patches.Wedge at 0x7fb7cdf0c050>,
#   <matplotlib.patches.Wedge at 0x7fb7cdf0c850>,
#   <matplotlib.patches.Wedge at 0x7fb7cdedb090>,
#   <matplotlib.patches.Wedge at 0x7fb7cdedb890>,
#   <matplotlib.patches.Wedge at 0x7fb7cd34d0d0>,
#   <matplotlib.patches.Wedge at 0x7fb7cd34d8d0>,
#   <matplotlib.patches.Wedge at 0x7fb7cd36c110>,
#   <matplotlib.patches.Wedge at 0x7fb7cd36c910>,
#   <matplotlib.patches.Wedge at 0x7fb7cd35e150>],
#  [Text(1.09404,0.114379,'Jan'),
#   Text(0.990519,0.478405,'Feb'),
#   Text(0.499863,0.979866,'Mar'),
#   Text(-0.329308,1.04955,'April'),
#   Text(-0.93062,0.586469,'May'),
#   Text(-1.09834,-0.0604643,'June'),
#   Text(-0.913463,-0.924979,'July'),
#   Text(-0.233388,-1.07496,'Aug'),
#   Text(0.0210976,-1.0998,'Sept'),
#   Text(0.460981,-0.998747,'Oct'),
#   Text(0.886871,-0.650738,'Nov'),
#   Text(1.0761,-0.228076,'Dec')],
#  [Text(0.596748,0.0623883,'3.3%'),
#   Text(0.540283,0.260948,'7.7%'),
#   Text(0.272653,0.534472,'13.0%'),
#   Text(-0.179623,0.572482,'11.7%'),
#   Text(-0.507611,0.319892,'10.7%'),
#   Text(-0.599093,-0.0329806,'8.9%'),
#   Text(-0.562131,-0.569218,'14.5%'),
#   Text(-0.127302,-0.58634,'3.5%'),
#   Text(0.0115078,-0.59989,'3.9%'),
#   Text(0.251444,-0.544771,'9.2%'),
#   Text(0.483748,-0.354948,'6.9%'),
#   Text(0.586961,-0.124405,'6.6%')])

# %%
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb7cd407890>,
#   <matplotlib.patches.Wedge at 0x7fb7cd8ef0d0>,
#   <matplotlib.patches.Wedge at 0x7fb7cd8ef8d0>,
#   <matplotlib.patches.Wedge at 0x7fb7cd90c110>,
#   <matplotlib.patches.Wedge at 0x7fb7cd90c910>,
#   <matplotlib.patches.Wedge at 0x7fb7cd914150>,
#   <matplotlib.patches.Wedge at 0x7fb7cd914950>,
#   <matplotlib.patches.Wedge at 0x7fb7cd916190>,
#   <matplotlib.patches.Wedge at 0x7fb7cd916990>,
#   <matplotlib.patches.Wedge at 0x7fb7cd1c91d0>,
#   <matplotlib.patches.Wedge at 0x7fb7cd1c99d0>,
#   <matplotlib.patches.Wedge at 0x7fb7cd1fb210>],
#  [Text(1.09404,0.114379,'Jan'),
#   Text(0.990519,0.478405,'Feb'),
#   Text(0.499863,0.979866,'Mar'),
#   Text(-0.329308,1.04955,'April'),
#   Text(-0.93062,0.586469,'May'),
#   Text(-1.09834,-0.0604643,'June'),
#   Text(-0.913463,-0.924979,'July'),
#   Text(-0.233388,-1.07496,'Aug'),
#   Text(0.0210976,-1.0998,'Sept'),
#   Text(0.460981,-0.998747,'Oct'),
#   Text(0.886871,-0.650738,'Nov'),
#   Text(1.0761,-0.228076,'Dec')],
#  [Text(0.596748,0.0623883,'3.3%'),
#   Text(0.540283,0.260948,'7.7%'),
#   Text(0.272653,0.534472,'13.0%'),
#   Text(-0.179623,0.572482,'11.7%'),
#   Text(-0.507611,0.319892,'10.7%'),
#   Text(-0.599093,-0.0329806,'8.9%'),
#   Text(-0.562131,-0.569218,'14.5%'),
#   Text(-0.127302,-0.58634,'3.5%'),
#   Text(0.0115078,-0.59989,'3.9%'),
#   Text(0.251444,-0.544771,'9.2%'),
#   Text(0.483748,-0.354948,'6.9%'),
#   Text(0.586961,-0.124405,'6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
### Create a Pie Chart Using the Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
#Explode the two highest percentage months.
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
#Increase the figure size to 8x8.
fig, ax = plt.subplots(figsize=(8,8))
#Add a percentage to one decimal place to each wedge of the pie.
#Add new colors of your own choosing or use the colors from the previous pie chart.
#Add a shadow.
#Add a start angle so that January is at the top.
#Reverse the order so that the month order is in a clockwise direction.
ax.pie(y_axis,labels=x_axis,explode=explode_values,autopct='%.1f%%', 
       colors=colors,shadow=True, startangle=95, counterclock=True)

plt.show()
